# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

##Load the extracted features from the pretrained model 
features = np.load('../out_TrainedModel/dataset3_features.npy')
labels = np.load('../out_TrainedModel/dataset3_labels.npy')

print(features.shape)
print(labels.shape)
# Out:
# (794, 512)
# (794,)

# %%
##split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    features, labels, test_size=0.3, random_state=42, stratify=labels
)


print("Training set shape:", X_train.shape)
print("Test set shape:", X_test.shape)
# Out:
# Training set shape: (555, 512)
# Test set shape: (239, 512)

# %%
##scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

##train the model
linear_svm = SVC(kernel='linear', C=1.0, random_state=42)
linear_svm.fit(X_train_scaled, y_train)

##make predictions
y_pred = linear_svm.predict(X_test_scaled)

##evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print("Classification Report:")
print(classification_report(y_test, y_pred, target_names= ['Cat', 'Dog', 'Wild']))

print("Confusion Matrix:")
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Cat', 'Dog', 'Wild'])
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy: 54.39%
# Classification Report:
#               precision    recall  f1-score   support
#
#          Cat       0.51      0.56      0.53        77
#          Dog       0.60      0.59      0.59        78
#         Wild       0.53      0.49      0.51        84
#
#     accuracy                           0.54       239
#    macro avg       0.55      0.55      0.54       239
# weighted avg       0.55      0.54      0.54       239
#
# Confusion Matrix:
